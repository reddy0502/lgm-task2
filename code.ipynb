# %%
import numpy as np
import pandas as pd
import datetime
import math
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense , LSTM
from sklearn.metrics import mean_squared_error

# %%
Dataset_link="C:/Users/reddy/OneDrive/Desktop/LGM_internship-main/task-2/NSE-TATAGLOBAL.csv"

# %%
df= pd.read_csv(Dataset_link, parse_dates=True,)
df.reset_index()
df.head(10)
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
# 5  2018-09-21  235.00  237.00  227.95  233.75  234.60               5395319
# 6  2018-09-19  235.95  237.20  233.45  234.60  234.90               1362058
# 7  2018-09-18  237.90  239.25  233.50  235.50  235.05               2614794
# 8  2018-09-17  233.15  238.00  230.25  236.40  236.60               3170894
# 9  2018-09-14  223.45  236.70  223.30  234.00  233.95               6377909
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55
# 5         12589.59
# 6          3202.78
# 7          6163.70
# 8          7445.41
# 9         14784.50

# %%
df.sample(10)
# Out:
#             Date    Open    High     Low    Last   Close  \
# 158   2018-02-07  270.00  284.40  270.00  279.65  280.15
# 305   2017-07-07  153.15  158.90  153.10  157.65  157.75
# 800   2015-07-07  135.60  141.65  135.10  138.05  138.20
# 1428  2012-12-20  165.00  165.35  162.30  163.15  162.95
# 1234  2013-09-30  146.00  146.05  143.15  143.50  143.85
# 970   2014-10-29  157.00  158.25  156.60  157.40  157.30
# 1814  2011-06-06   92.30   97.00   92.10   92.85   93.15
# 845   2015-05-05  143.85  145.90  143.50  144.60  144.55
# 163   2018-01-31  302.90  303.70  286.10  291.15  290.65
# 29    2018-08-14  235.00  238.50  235.00  237.40  237.55
#
#       Total Trade Quantity  Turnover (Lacs)
# 158                8055761         22500.69
# 305                6442241         10106.02
# 800                3133999          4355.13
# 1428               1960923          3202.39
# 1234                785467          1133.32
# 970                1079352          1700.60
# 1814                337230           315.75
# 845                1785800          2584.34
# 163                5397599         15929.24
# 29                 1885288          4459.96

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Last', 'Close', 'Total Trade Quantity',
#        'Turnover (Lacs)'],
#       dtype='object')

# %%
df.shape
# Out:
# (2035, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %%
df.isnull().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
df.describe()
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %%
plt.figure(figsize=(10,6))
df['Close'].plot(kind='line',figsize=(16,7),color='r',label="Closing Price")

plt.ylabel("Price")
plt.legend(loc="upper right")
plt.title("Change in closing price over the years")
plt.grid()

# %%
plt.figure(figsize=(10,6))
df['Open'].plot(kind='line',figsize=(16,7),color='y',label="Opening Price")

plt.ylabel("Price")
plt.legend(loc="upper left")
plt.title("Change in opening price over the years")
plt.grid()

# %%
df1=df.reset_index()['Close']
df1
# Out:
# 0       233.75
# 1       233.25
# 2       234.25
# 3       236.10
# 4       233.30
#          ...
# 2030    118.65
# 2031    117.60
# 2032    120.65
# 2033    120.90
# 2034    121.55
# Name: Close, Length: 2035, dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(),annot=True,cmap='BuPu')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(11,5))
plt.subplot(1,2,1)
sns.boxplot(data=df,y='Total Trade Quantity',color='green')
plt.subplot(1,2,2)
sns.boxplot(data=df,y='Turnover (Lacs)',color='red')
# Out:
# <Axes: ylabel='Turnover (Lacs)'>

# %%
fig=plt.figure(figsize=(7,6))
plt.scatter(df['Total Trade Quantity'],df['Turnover (Lacs)'], alpha=0.5, edgecolor='r', color='cyan')
plt.xlabel("Trade Quantity (in 100000)")
plt.ylabel("Turnover (in lacs)")
plt.title(" Selling Units Vs Turnover")
plt.show()

# %%
training_set= df[['Open']]
training_set=pd.DataFrame(training_set)
training_set
# Out:
#         Open
# 0     234.05
# 1     234.55
# 2     240.00
# 3     233.30
# 4     233.55
# ...      ...
# 2030  117.60
# 2031  120.10
# 2032  121.80
# 2033  120.30
# 2034  122.10
#
# [2035 rows x 1 columns]

# %%
scaler=MinMaxScaler(feature_range=(0,1))
training_set_scaler=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
training_set_scaler
# Out:
# array([[0.62418301],
#        [0.62214052],
#        [0.62622549],
#        ...,
#        [0.1621732 ],
#        [0.16319444],
#        [0.16584967]])

# %%
train_size1= int(len(training_set_scaler)*0.65)
test_size1=int(len(training_set_scaler))-train_size1
train_data1,test_data1=training_set_scaler[0:train_size1,:],training_set_scaler[train_size1:len(df),:1]

# %%
train_size1
# Out:
# 1322

# %%
def create_dataset(dataset,time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step=100
x_train, y_train=create_dataset(train_data1, time_step)
x_test, y_test= create_dataset(test_data1, time_step)

# %%
print(x_train.shape,y_train.shape)
# Out:
# (1221, 100) (1221,)

# %%
x_test.shape
# Out:
# (612, 100)

# %%
y_test.shape
# Out:
# (612,)

# %%
x_train = x_train.reshape(x_train.shape[0],x_train.shape[1] , 1)
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1] , 1)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100,1)))
model.add(LSTM(50, return_sequences=True, input_shape=(100,1)))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam', metrics='acc')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, validation_data = (x_test, y_test), epochs = 75, batch_size = 64, verbose = 1)
# Out:
# Epoch 1/75
# 20/20 [==============================] - 10s 253ms/step - loss: 0.0310 - acc: 0.0000e+00 - val_loss: 0.0057 - val_acc: 0.0016
# Epoch 2/75
# 20/20 [==============================] - 4s 190ms/step - loss: 0.0032 - acc: 8.1900e-04 - val_loss: 0.0011 - val_acc: 0.0016
# Epoch 3/75
# 20/20 [==============================] - 4s 197ms/step - loss: 0.0020 - acc: 8.1900e-04 - val_loss: 0.0012 - val_acc: 0.0016
# Epoch 4/75
# 20/20 [==============================] - 4s 194ms/step - loss: 0.0021 - acc: 8.1900e-04 - val_loss: 0.0015 - val_acc: 0.0016
# Epoch 5/75
# 20/20 [==============================] - 4s 201ms/step - loss: 0.0018 - acc: 8.1900e-04 - val_loss: 0.0011 - val_acc: 0.0016
# Epoch 6/75
# 20/20 [==============================] - 4s 188ms/step - loss: 0.0016 - acc: 8.1900e-04 - val_loss: 0.0013 - val_acc: 0.0016
# Epoch 7/75
# 20/20 [==============================] - 4s 205ms/step - loss: 0.0016 - acc: 8.1900e-04 - val_loss: 0.0011 - val_acc: 0.0016
# Epoch 8/75
# 20/20 [==============================] - 4s 200ms/step - loss: 0.0015 - acc: 8.1900e-04 - val_loss: 0.0016 - val_acc: 0.0016
# Epoch 9/75
# 20/20 [==============================] - 4s 200ms/step - loss: 0.0015 - acc: 8.1900e-04 - val_loss: 0.0013 - val_acc: 0.0016
# Epoch 10/75
# 20/20 [==============================] - 4s 212ms/step - loss: 0.0015 - acc: 8.1900e-04 - val_loss: 0.0014 - val_acc: 0.0016
# Epoch 11/75
# 20/20 [==============================] - 4s 202ms/step - loss: 0.0013 - acc: 8.1900e-04 - val_loss: 0.0011 - val_acc: 0.0016
# Epoch 12/75
# 20/20 [==============================] - 4s 209ms/step - loss: 0.0013 - acc: 8.1900e-04 - val_loss: 0.0012 - val_acc: 0.0016
# Epoch 13/75
# 20/20 [==============================] - 4s 204ms/step - loss: 0.0012 - acc: 8.1900e-04 - val_loss: 0.0010 - val_acc: 0.0016
# Epoch 14/75
# 20/20 [==============================] - 4s 211ms/step - loss: 0.0011 - acc: 8.1900e-04 - val_loss: 0.0012 - val_acc: 0.0016
# Epoch 15/75
# 20/20 [==============================] - 4s 210ms/step - loss: 0.0010 - acc: 8.1900e-04 - val_loss: 9.2210e-04 - val_acc: 0.0016
# Epoch 16/75
# 20/20 [==============================] - 4s 220ms/step - loss: 0.0011 - acc: 8.1900e-04 - val_loss: 8.1878e-04 - val_acc: 0.0016
# Epoch 17/75
# 20/20 [==============================] - 4s 206ms/step - loss: 9.5130e-04 - acc: 8.1900e-04 - val_loss: 9.4398e-04 - val_acc: 0.0016
# Epoch 18/75
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0010 - acc: 8.1900e-04 - val_loss: 6.5297e-04 - val_acc: 0.0016
# Epoch 19/75
# 20/20 [==============================] - 4s 211ms/step - loss: 0.0013 - acc: 8.1900e-04 - val_loss: 9.6496e-04 - val_acc: 0.0016
# Epoch 20/75
# 20/20 [==============================] - 4s 208ms/step - loss: 9.2798e-04 - acc: 8.1900e-04 - val_loss: 9.8674e-04 - val_acc: 0.0016
# Epoch 21/75
# 20/20 [==============================] - 4s 205ms/step - loss: 8.4953e-04 - acc: 8.1900e-04 - val_loss: 7.7273e-04 - val_acc: 0.0016
# Epoch 22/75
# 20/20 [==============================] - 4s 202ms/step - loss: 8.4618e-04 - acc: 8.1900e-04 - val_loss: 7.9091e-04 - val_acc: 0.0016
# Epoch 23/75
# 20/20 [==============================] - 4s 207ms/step - loss: 8.0862e-04 - acc: 8.1900e-04 - val_loss: 9.4353e-04 - val_acc: 0.0016
# Epoch 24/75
# 20/20 [==============================] - 4s 209ms/step - loss: 8.0596e-04 - acc: 8.1900e-04 - val_loss: 7.3912e-04 - val_acc: 0.0016
# Epoch 25/75
# 20/20 [==============================] - 4s 200ms/step - loss: 8.1163e-04 - acc: 8.1900e-04 - val_loss: 6.5005e-04 - val_acc: 0.0016
# Epoch 26/75
# 20/20 [==============================] - 4s 207ms/step - loss: 8.4187e-04 - acc: 8.1900e-04 - val_loss: 0.0011 - val_acc: 0.0016
# Epoch 27/75
# 20/20 [==============================] - 4s 211ms/step - loss: 8.9508e-04 - acc: 8.1900e-04 - val_loss: 8.6733e-04 - val_acc: 0.0016
# Epoch 28/75
# 20/20 [==============================] - 4s 206ms/step - loss: 7.0373e-04 - acc: 8.1900e-04 - val_loss: 6.9125e-04 - val_acc: 0.0016
# Epoch 29/75
# 20/20 [==============================] - 4s 195ms/step - loss: 8.9676e-04 - acc: 8.1900e-04 - val_loss: 7.3914e-04 - val_acc: 0.0016
# Epoch 30/75
# 20/20 [==============================] - 4s 184ms/step - loss: 6.9111e-04 - acc: 8.1900e-04 - val_loss: 8.3661e-04 - val_acc: 0.0016
# Epoch 31/75
# 20/20 [==============================] - 4s 187ms/step - loss: 6.4279e-04 - acc: 8.1900e-04 - val_loss: 7.6401e-04 - val_acc: 0.0016
# Epoch 32/75
# 20/20 [==============================] - 4s 187ms/step - loss: 6.2685e-04 - acc: 8.1900e-04 - val_loss: 9.5662e-04 - val_acc: 0.0016
# Epoch 33/75
# 20/20 [==============================] - 4s 185ms/step - loss: 6.4787e-04 - acc: 8.1900e-04 - val_loss: 8.4331e-04 - val_acc: 0.0016
# Epoch 34/75
# 20/20 [==============================] - 4s 186ms/step - loss: 9.3999e-04 - acc: 8.1900e-04 - val_loss: 0.0011 - val_acc: 0.0016
# Epoch 35/75
# 20/20 [==============================] - 4s 189ms/step - loss: 6.6911e-04 - acc: 8.1900e-04 - val_loss: 6.3200e-04 - val_acc: 0.0016
# Epoch 36/75
# 20/20 [==============================] - 4s 190ms/step - loss: 6.1853e-04 - acc: 8.1900e-04 - val_loss: 7.7633e-04 - val_acc: 0.0016
# Epoch 37/75
# 20/20 [==============================] - 4s 186ms/step - loss: 5.8627e-04 - acc: 8.1900e-04 - val_loss: 6.3918e-04 - val_acc: 0.0016
# Epoch 38/75
# 20/20 [==============================] - 4s 184ms/step - loss: 5.9154e-04 - acc: 8.1900e-04 - val_loss: 7.8839e-04 - val_acc: 0.0016
# Epoch 39/75
# 20/20 [==============================] - 4s 185ms/step - loss: 5.9167e-04 - acc: 8.1900e-04 - val_loss: 6.0174e-04 - val_acc: 0.0016
# Epoch 40/75
# 20/20 [==============================] - 4s 188ms/step - loss: 5.6863e-04 - acc: 8.1900e-04 - val_loss: 5.6017e-04 - val_acc: 0.0016
# Epoch 41/75
# 20/20 [==============================] - 4s 182ms/step - loss: 5.3867e-04 - acc: 8.1900e-04 - val_loss: 6.3907e-04 - val_acc: 0.0016
# Epoch 42/75
# 20/20 [==============================] - 4s 183ms/step - loss: 5.2626e-04 - acc: 8.1900e-04 - val_loss: 5.0207e-04 - val_acc: 0.0016
# Epoch 43/75
# 20/20 [==============================] - 4s 183ms/step - loss: 6.2323e-04 - acc: 8.1900e-04 - val_loss: 5.5424e-04 - val_acc: 0.0016
# Epoch 44/75
# 20/20 [==============================] - 4s 189ms/step - loss: 5.0282e-04 - acc: 8.1900e-04 - val_loss: 5.5493e-04 - val_acc: 0.0016
# Epoch 45/75
# 20/20 [==============================] - 4s 185ms/step - loss: 4.8245e-04 - acc: 8.1900e-04 - val_loss: 5.9632e-04 - val_acc: 0.0016
# Epoch 46/75
# 20/20 [==============================] - 4s 186ms/step - loss: 4.6787e-04 - acc: 8.1900e-04 - val_loss: 4.3678e-04 - val_acc: 0.0016
# Epoch 47/75
# 20/20 [==============================] - 4s 183ms/step - loss: 4.5885e-04 - acc: 8.1900e-04 - val_loss: 4.5916e-04 - val_acc: 0.0016
# Epoch 48/75
# 20/20 [==============================] - 4s 186ms/step - loss: 5.1272e-04 - acc: 8.1900e-04 - val_loss: 7.4994e-04 - val_acc: 0.0016
# Epoch 49/75
# 20/20 [==============================] - 4s 184ms/step - loss: 4.6424e-04 - acc: 8.1900e-04 - val_loss: 4.3275e-04 - val_acc: 0.0016
# Epoch 50/75
# 20/20 [==============================] - 4s 183ms/step - loss: 4.6323e-04 - acc: 8.1900e-04 - val_loss: 4.4025e-04 - val_acc: 0.0016
# Epoch 51/75
# 20/20 [==============================] - 4s 184ms/step - loss: 6.0698e-04 - acc: 8.1900e-04 - val_loss: 0.0011 - val_acc: 0.0016
# Epoch 52/75
# 20/20 [==============================] - 4s 184ms/step - loss: 0.0011 - acc: 8.1900e-04 - val_loss: 7.5862e-04 - val_acc: 0.0016
# Epoch 53/75
# 20/20 [==============================] - 4s 190ms/step - loss: 4.4174e-04 - acc: 8.1900e-04 - val_loss: 4.2815e-04 - val_acc: 0.0016
# Epoch 54/75
# 20/20 [==============================] - 4s 185ms/step - loss: 4.0890e-04 - acc: 8.1900e-04 - val_loss: 3.8189e-04 - val_acc: 0.0016
# Epoch 55/75
# 20/20 [==============================] - 4s 182ms/step - loss: 3.9410e-04 - acc: 8.1900e-04 - val_loss: 3.8338e-04 - val_acc: 0.0016
# Epoch 56/75
# 20/20 [==============================] - 4s 183ms/step - loss: 4.4716e-04 - acc: 8.1900e-04 - val_loss: 4.4934e-04 - val_acc: 0.0016
# Epoch 57/75
# 20/20 [==============================] - 4s 185ms/step - loss: 3.7963e-04 - acc: 8.1900e-04 - val_loss: 4.1971e-04 - val_acc: 0.0016
# Epoch 58/75
# 20/20 [==============================] - 4s 184ms/step - loss: 3.7960e-04 - acc: 8.1900e-04 - val_loss: 3.3775e-04 - val_acc: 0.0016
# Epoch 59/75
# 20/20 [==============================] - 4s 181ms/step - loss: 4.3143e-04 - acc: 8.1900e-04 - val_loss: 4.2248e-04 - val_acc: 0.0016
# Epoch 60/75
# 20/20 [==============================] - 4s 181ms/step - loss: 3.4937e-04 - acc: 8.1900e-04 - val_loss: 3.7188e-04 - val_acc: 0.0016
# Epoch 61/75
# 20/20 [==============================] - 4s 182ms/step - loss: 3.6006e-04 - acc: 8.1900e-04 - val_loss: 3.5858e-04 - val_acc: 0.0016
# Epoch 62/75
# 20/20 [==============================] - 4s 185ms/step - loss: 3.5942e-04 - acc: 8.1900e-04 - val_loss: 3.7788e-04 - val_acc: 0.0016
# Epoch 63/75
# 20/20 [==============================] - 4s 183ms/step - loss: 3.2352e-04 - acc: 8.1900e-04 - val_loss: 3.4533e-04 - val_acc: 0.0016
# Epoch 64/75
# 20/20 [==============================] - 4s 182ms/step - loss: 3.2750e-04 - acc: 8.1900e-04 - val_loss: 3.0790e-04 - val_acc: 0.0016
# Epoch 65/75
# 20/20 [==============================] - 4s 185ms/step - loss: 3.2592e-04 - acc: 8.1900e-04 - val_loss: 5.3284e-04 - val_acc: 0.0016
# Epoch 66/75
# 20/20 [==============================] - 4s 186ms/step - loss: 4.7460e-04 - acc: 8.1900e-04 - val_loss: 3.2630e-04 - val_acc: 0.0016
# Epoch 67/75
# 20/20 [==============================] - 4s 184ms/step - loss: 3.3018e-04 - acc: 8.1900e-04 - val_loss: 3.0963e-04 - val_acc: 0.0016
# Epoch 68/75
# 20/20 [==============================] - 4s 183ms/step - loss: 3.0362e-04 - acc: 8.1900e-04 - val_loss: 3.1574e-04 - val_acc: 0.0016
# Epoch 69/75
# 20/20 [==============================] - 4s 181ms/step - loss: 2.9470e-04 - acc: 8.1900e-04 - val_loss: 3.2141e-04 - val_acc: 0.0016
# Epoch 70/75
# 20/20 [==============================] - 4s 186ms/step - loss: 3.1908e-04 - acc: 8.1900e-04 - val_loss: 4.6565e-04 - val_acc: 0.0016
# Epoch 71/75
# 20/20 [==============================] - 4s 186ms/step - loss: 3.5989e-04 - acc: 8.1900e-04 - val_loss: 2.8678e-04 - val_acc: 0.0016
# Epoch 72/75
# 20/20 [==============================] - 4s 181ms/step - loss: 3.0348e-04 - acc: 8.1900e-04 - val_loss: 3.7977e-04 - val_acc: 0.0016
# Epoch 73/75
# 20/20 [==============================] - 4s 184ms/step - loss: 2.9438e-04 - acc: 8.1900e-04 - val_loss: 2.7957e-04 - val_acc: 0.0016
# Epoch 74/75
# 20/20 [==============================] - 4s 184ms/step - loss: 3.3264e-04 - acc: 8.1900e-04 - val_loss: 3.0000e-04 - val_acc: 0.0016
# Epoch 75/75
# 20/20 [==============================] - 4s 186ms/step - loss: 2.7391e-04 - acc: 8.1900e-04 - val_loss: 2.6102e-04 - val_acc: 0.0016

# %%
train_predict1=model.predict(x_train)
test_predict1=model.predict(x_test)
#Transformback to original form
train_predict1=scaler.inverse_transform(train_predict1)
test_predict1=scaler.inverse_transform(test_predict1)
# Out:
# 39/39 [==============================] - 3s 40ms/step
# 20/20 [==============================] - 1s 40ms/step

# %%
math.sqrt(mean_squared_error(y_train,train_predict1))
# Out:
# 164.80919185646604

# %%
math.sqrt(mean_squared_error(y_test,test_predict1))
# Out:
# 115.83771300592433

# %%
### Plotting
# shift train predictions for plotting
look_back=100
trainPredictPlot = np.empty_like(training_set_scaler)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict1)+look_back, :] = train_predict1

# shift test predictions for plotting
testPredictPlot = np.empty_like(training_set_scaler)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict1)+(look_back*2)+1:len(df1)-1, :] = test_predict1

# plot baseline and predictions
plt.figure(figsize=(10,5))
plt.plot(scaler.inverse_transform(training_set_scaler))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
